# %% [markdown]
# <!-- TEACHABLE_PROJECT_NOTE -->
# # Test Notebook - Scratch Checks
#
# ## What this notebook does
# This notebook is a safe place for quick experiments, debugging, and small checks before moving stable work into the main notebooks or script.
#
# ## How to learn from it
# - Use scratch notebooks to test an idea quickly without disturbing the main pipeline.
# - When a test becomes useful and repeatable, move it into a cleaner notebook or Python function.
# - Keep notes about what each experiment proves so future readers know whether to keep or discard it.
#
# ## Documentation added
# I added this Markdown guide so the notebook explains its role before the code begins. Read this cell first, then run the code cells from top to bottom and connect each step back to the pipeline flow in README.md.

# %% [markdown]
# # Quick Silver Dataset Check
#
# This small notebook is for lightweight checks after running the silver layer. It confirms that `silver.csv` exists, loads correctly, and has the expected columns.

# %% [markdown]
# ## Setup and Load Data
#
# Read the cleaned silver dataset.

# %%
from pathlib import Path

import pandas as pd

SILVER_DATA_PATH = Path("silver.csv")
df_silver = pd.read_csv(SILVER_DATA_PATH)

# %% [markdown]
# ## Basic Shape
#
# Check how many rows and columns are available.

# %%
df_silver.shape

# %% [markdown]
# ## Column List
#
# Review the final column names created by the silver cleaning notebook.

# %%
df_silver.columns.tolist()

# %% [markdown]
# ## Preview Records
#
# Look at the first few cleaned rows.

# %%
df_silver.head()
