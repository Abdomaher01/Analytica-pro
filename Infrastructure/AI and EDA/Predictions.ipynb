# %% [markdown]
# # Advanced Predictions and Business Insights
#
# This notebook is the guided entry point for the full analytics pipeline in `advanced_insights.py`. It reads `silver.csv`, creates the required `outputs/` structure, trains predictive models, explains drivers with SHAP, segments user/post behavior, detects anomalies, forecasts next-month trends, analyzes propagation networks, and writes executive-ready reports.

# %% [markdown]
# ## Output Structure
#
# Running the pipeline creates:
#
# - `outputs/models/` for trained models
# - `outputs/plots/` for visualizations
# - `outputs/reports/` for metrics, feature importance, and business reports
# - `outputs/datasets/` for scored datasets, clusters, anomalies, and forecasts

# %% [markdown]
# ## Run the Complete Pipeline
#
# This single cell executes the whole workflow end to end. GPU acceleration is auto-detected (`--xgboost-device auto`). If optional packages such as Prophet or SHAP are unavailable, the script uses documented fallbacks where possible and writes the status into the reports.

# %%
# %run advanced_insights.py --data ../Medalian/Silver.csv --output-dir . --xgboost-device cuda
# Out:
# 2026-07-17 16:02:25,952 | INFO | Advanced analytics pipeline started (resume=True, reuse_models=True)
# 2026-07-17 16:02:26,096 | INFO | Stage started: environment_setup
# 2026-07-17 16:02:26,152 | INFO | Training hardware: device=cuda cpu_cores=16 cpu_threads=16 gpu=NVIDIA GeForce RTX 2050
# 2026-07-17 16:02:26,153 | INFO | Current memory footprint: 558.26 MB
# 2026-07-17 16:02:26,154 | INFO | GPU memory: 81 MB used / 4096 MB total
# 2026-07-17 16:02:26,154 | INFO | Stage completed: environment_setup in 0.06 seconds
# 2026-07-17 16:02:26,155 | INFO | Stage started: data_loading
# 2026-07-17 16:02:26,232 | INFO | Loaded ../Medalian/Silver.csv with shape (50000, 33)
# 2026-07-17 16:02:26,270 | INFO | Stage completed: data_loading in 0.11 seconds
# 2026-07-17 16:02:26,270 | INFO | Checkpoint saved after stage: data_loading
# 2026-07-17 16:02:26,271 | INFO | Stage started: feature_engineering
# 2026-07-17 16:02:26,286 | INFO | Stage completed: feature_engineering in 0.01 seconds
# 2026-07-17 16:02:26,287 | INFO | Checkpoint saved after stage: feature_engineering
# 2026-07-17 16:02:26,288 | INFO | Stage started: model_training
# 2026-07-17 16:02:26,288 | INFO | XGBoost training device: cuda (requested=cuda)
# 2026-07-17 16:02:26,289 | INFO | Starting XGBoost insight engine
# 2026-07-17 16:02:26,289 | INFO | Parameters: device=cuda, random_state=42, reuse_models=True, data_mtime=1783706648.7360027
# 2026-07-17 16:02:26,290 | INFO | Training XGBoost model for target: misinformation_probability
# 2026-07-17 16:02:26,290 | INFO | Training XGBoost model for misinformation_probability
# 2026-07-17 16:02:47,848 | INFO | Model tuning completed in 20.73 seconds on cuda
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 2026-07-17 16:02:55,953 | INFO | Model misinformation_probability trained in 28.80 seconds on cuda
# 2026-07-17 16:02:55,953 | INFO | Model misinformation_probability resource usage: cpu_threads=16 peak_rss_mb=625.11 gpu=NVIDIA GeForce RTX 2050
# 2026-07-17 16:02:55,954 | INFO | Model misinformation_probability GPU memory: 83 MB used / 4096 MB total
# 2026-07-17 16:02:55,955 | INFO | Checkpoint saved after stage: xgboost_misinformation_probability
# 2026-07-17 16:02:55,955 | INFO | Successfully trained XGBoost model for misinformation_probability
# 2026-07-17 16:02:55,956 | INFO | Training XGBoost model for target: credibility_score
# 2026-07-17 16:02:55,957 | INFO | Training XGBoost model for credibility_score
# 2026-07-17 16:03:15,680 | INFO | Model tuning completed in 18.35 seconds on cuda
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/abdo/Projects/mlearn/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 2026-07-17 16:03:24,452 | INFO | Model credibility_score trained in 27.07 seconds on cuda
# 2026-07-17 16:03:24,452 | INFO | Model credibility_score resource usage: cpu_threads=16 peak_rss_mb=639.98 gpu=NVIDIA GeForce RTX 2050
# 2026-07-17 16:03:24,453 | INFO | Model credibility_score GPU memory: 83 MB used / 4096 MB total
# 2026-07-17 16:03:24,454 | INFO | Checkpoint saved after stage: xgboost_credibility_score
# 2026-07-17 16:03:24,454 | INFO | Successfully trained XGBoost model for credibility_score
# 2026-07-17 16:03:24,455 | INFO | Writing XGBoost reports for 2 targets: ['misinformation_probability', 'credibility_score']
# 2026-07-17 16:03:24,506 | INFO | Stage completed: model_training in 56.03 seconds
# 2026-07-17 16:03:24,507 | INFO | Checkpoint saved after stage: model_training
# 2026-07-17 16:03:24,508 | INFO | Stage started: shap_explainability
# 2026-07-17 16:03:24,508 | INFO | Starting SHAP explainability
# 2026-07-17 16:03:24,508 | WARNING | SHAP is not available in this environment: Numba needs NumPy 2.4 or less. Got NumPy 2.5.
# 2026-07-17 16:03:24,509 | INFO | Checkpoint saved after stage: shap
# 2026-07-17 16:03:24,510 | INFO | Stage completed: shap_explainability in 0.00 seconds
# 2026-07-17 16:03:24,510 | INFO | Stage started: preprocessing
# 2026-07-17 16:03:24,536 | INFO | Stage completed: preprocessing in 0.03 seconds
# 2026-07-17 16:03:24,537 | INFO | Checkpoint saved after stage: preprocessing
# 2026-07-17 16:03:24,538 | INFO | Stage started: clustering_training
# 2026-07-17 16:03:24,538 | INFO | Starting user and post segmentation
# 2026-07-17 16:03:24,541 | INFO | Clustering subsample used: n=50000 sample=10000 max=10000
# 2026-07-17 16:04:36,873 | INFO | Clustering subsample used: n=50000 sample=10000 max=10000
# 2026-07-17 16:04:39,027 | INFO | Skipping Agglomerative Clustering evaluation (n=50000, max=5000).
# 2026-07-17 16:04:39,601 | INFO | Checkpoint saved after stage: clustering
# 2026-07-17 16:04:39,602 | INFO | Stage completed: clustering_training in 73.10 seconds
# 2026-07-17 16:04:39,603 | INFO | Stage started: anomaly_detection
# 2026-07-17 16:04:39,603 | INFO | Starting anomaly detection
# 2026-07-17 16:04:44,879 | INFO | Checkpoint saved after stage: anomaly_detection
# 2026-07-17 16:04:44,880 | INFO | Stage completed: anomaly_detection in 4.29 seconds
# 2026-07-17 16:04:44,880 | INFO | Stage started: forecasting
# 2026-07-17 16:04:44,881 | INFO | Starting time-series forecasting
# 2026-07-17 16:04:44,942 | INFO | Chain [1] start processing
# 2026-07-17 16:04:45,028 | INFO | Chain [1] done processing
# 2026-07-17 16:04:45,419 | INFO | Chain [1] start processing
# 2026-07-17 16:04:45,513 | INFO | Chain [1] done processing
# 2026-07-17 16:04:45,866 | INFO | Chain [1] start processing
# 2026-07-17 16:04:45,975 | INFO | Chain [1] done processing
# 2026-07-17 16:04:46,319 | INFO | Chain [1] start processing
# 2026-07-17 16:04:46,376 | INFO | Chain [1] done processing
# 2026-07-17 16:04:46,687 | INFO | Checkpoint saved after stage: forecasting
# 2026-07-17 16:04:46,687 | INFO | Stage completed: forecasting in 1.81 seconds
# 2026-07-17 16:04:46,688 | INFO | Stage started: executive_summary
# 2026-07-17 16:04:46,690 | INFO | Checkpoint saved after stage: executive_summary
# 2026-07-17 16:04:46,691 | INFO | Stage completed: executive_summary in 0.00 seconds
# 2026-07-17 16:04:46,691 | INFO | Stage started: insights_reporting
# 2026-07-17 16:04:46,707 | INFO | Checkpoint saved after stage: insights_reporting
# 2026-07-17 16:04:46,708 | INFO | Stage completed: insights_reporting in 0.02 seconds
# 2026-07-17 16:04:46,709 | INFO | Pipeline completed. Outputs saved to outputs
# 2026-07-17 16:04:46,709 | INFO | Stage timings: {'environment_setup': 0.05818067699965468, 'data_loading': 0.11462989999927231, 'feature_engineering': 0.014973907999774383, 'model_training': 56.03454419700029, 'shap_explainability': 0.002303350000147475, 'preprocessing': 0.025830752999354445, 'clustering_training': 73.09610812000028, 'anomaly_detection': 4.291606671000409, 'forecasting': 1.8070535540000492, 'executive_summary': 0.002632044000165479, 'insights_reporting': 0.01677597399975639}

# %% [markdown]
# ## Review Executive Summary
#
# The executive summary answers the main stakeholder questions: retained predictive models, misinformation drivers, credibility traits, user groups, anomalies, next-month trends, and strategic recommendations.

# %%
from pathlib import Path

summary_path = Path("outputs/reports/executive_summary.txt")
print(summary_path.read_text(encoding="utf-8"))
# Out:
# Executive Summary
# =================
#
# 1. Which predictive models were retained?
# The retained workflow focuses on the strongest targets: Misinformation Probability, Credibility Score. The engagement-velocity target was removed from the production pipeline because it did not achieve a stable predictive fit and offered limited additional value over the retained models.
#
# 2. What drives misinformation?
# Misinformation risk is most strongly associated with risk_minus_credibility. This signal should be prioritized in moderation queues and early-warning dashboards.
#
# 3. What characterizes credible content?
# Credibility is most strongly associated with sentiment_score. Stakeholders should amplify content patterns that match this profile and audit posts that move in the opposite direction.
#
# 4. Which user groups exist?
# The segmentation model identified 3 K-Means user/post groups. These groups separate audiences by engagement, credibility, toxicity, and misinformation risk, enabling differentiated response strategies.
#
# 5. Which anomalies were discovered?
# IsolationForest flagged 8,781 unusual records. These records show rare combinations of audience size, engagement, toxicity, credibility, and misinformation risk, making them strong candidates for human review.
#
# 6. What trends are expected next month?
# The forecast suggests an downward misinformation trend, an upward credibility trend, and an upward post-volume trend over the next 30 days.
#
# 7. What are the most important strategic recommendations?
# - Build monitoring dashboards around the strongest misinformation and credibility drivers.
# - Prioritize anomalous high-risk records for analyst review.
# - Use cluster profiles to tailor crisis response messages by audience behavior.
# - Monitor engagement and credibility trends to detect emerging crises.
# - Re-run this pipeline after each major crisis phase to keep forecasts and model explanations current.

# %% [markdown]
# ## Inspect Model Metrics
#
# Each retained XGBoost target writes its own metrics file. These tables show predictive accuracy for misinformation probability and credibility score.

# %%
import pandas as pd

metric_files = sorted(Path("outputs/reports/xgboost").glob("xgboost_metrics_*.csv"))
metrics = pd.concat(
    [pd.read_csv(path).assign(model=path.stem.replace("xgboost_metrics_", "")) for path in metric_files],
    ignore_index=True,
)
metrics
# Out:
#         mae      rmse        r2  best_cv_rmse  training_seconds device_used  \
# 0  0.002725  0.003966  0.999495      0.004768         26.636469        cuda
# 1  0.002701  0.004004  0.999588      0.004726         28.343572        cuda
#
#                         model
# 0           credibility_score
# 1  misinformation_probability

# %% [markdown]
# ## Review Segments and Anomalies
#
# The clustered dataset contains the K-Means segment label and, when available, an HDBSCAN label. The anomalies file contains unusual records with a plain-English reason for review.

# %%
clustered = pd.read_csv("outputs/datasets/clustering/clustered_data.csv")
anomalies = pd.read_csv("outputs/datasets/anomaly_detection/anomalies.csv")

display(clustered[["post_id", "kmeans_cluster", "engagement_velocity", "misinformation_probability", "credibility_score"]].head())
display(anomalies[["post_id", "anomaly_score", "anomaly_reason"]].head())
# Out:
#    post_id  kmeans_cluster  engagement_velocity  misinformation_probability  \
# 0      1.0               0                7.808                       0.308
# 1      2.0               0               20.347                       0.110
# 2      3.0               2              143.045                       0.746
# 3      4.0               0               31.070                       0.095
# 4      5.0               0               21.411                       0.147
#
#    credibility_score
# 0              0.712
# 1              0.721
# 2              0.105
# 3              0.737
# 4              0.859
#    post_id  anomaly_score                                     anomaly_reason
# 0   8609.0      -0.205692  abnormal engagement spike; high misinformation...
# 1  19067.0      -0.204466  abnormal engagement spike; high misinformation...
# 2  34279.0      -0.200668           abnormal engagement spike; high toxicity
# 3  49933.0      -0.193163  abnormal engagement spike; high misinformation...
# 4  41020.0      -0.187809  abnormal engagement spike; high misinformation...

# %%
# Cluster evaluation summary
cluster_metrics = pd.read_csv("outputs/reports/kmeans/clustering_model_comparison.csv")
cluster_metrics
# Out:
#                  model_name  cluster_count  silhouette_score  \
# 0                   K-Means              3          0.312667
# 1  Agglomerative Clustering              3               NaN
# 2                    DBSCAN              1               NaN
#
#    davies_bouldin_index  calinski_harabasz_score  silhouette_sampled  \
# 0              1.740276               1517.35673               False
# 1                   NaN                      NaN               False
# 2                   NaN                      NaN               False
#
#    silhouette_sample_size      inertia     skipped_reason  is_best
# 0                   10000  77882.09375                NaN     True
# 1                       0          NaN  dataset_too_large    False
# 2                       0          NaN                NaN    False

# %%
# Anomaly evaluation summary
anomaly_metrics = pd.read_csv("outputs/reports/isolation_forest/anomaly_metrics.csv")
anomaly_metrics
# Out:
#    anomaly_count  total_records  anomaly_percentage  contamination_setting  \
# 0           8781          50000               17.56                    NaN
#
#    anomaly_ratio  score_min  score_max  score_mean  score_median  score_std  \
# 0         0.1756  -0.205692   0.130008    0.052064       0.07013   0.054015
#
#    score_p25  score_p75
# 0   0.025696   0.091695
